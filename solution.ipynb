# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Flatten, LSTM, Bidirectional, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

data = pd.read_csv('twitter4000.csv')

texts = data['twitts']
labels = data['sentiment']

max_words = 10000
max_len = 100

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

labels = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

embedding_dim = 50

def build_1d_cnn():
    model = Sequential([
        Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_len),
        Conv1D(filters=128, kernel_size=5, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def build_bilstm():
    model = Sequential([
        Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_len),
        Bidirectional(LSTM(64, return_sequences=True)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def build_lstm():
    model = Sequential([
        Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_len),
        LSTM(64, return_sequences=False),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def train_and_evaluate(model, model_name):
    print(f"\nTraining {model_name}...")
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=64,
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"{model_name} - Test Accuracy: {accuracy:.4f}")
    return history, accuracy

models = {
    "1D CNN": build_1d_cnn(),
    "BiLSTM": build_bilstm(),
    "LSTM": build_lstm()
}

results = {}
for model_name, model in models.items():
    history, accuracy = train_and_evaluate(model, model_name)
    results[model_name] = accuracy

print("\nModel Comparison:")
for model_name, accuracy in results.items():
    print(f"{model_name}: Test Accuracy = {accuracy:.4f}")
# Out:
# Training 1D CNN...
# Epoch 1/100
# c:\Users\HP\miniconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5174 - loss: 0.6947 - val_accuracy: 0.5500 - val_loss: 0.6889 - learning_rate: 0.0010
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6175 - loss: 0.6671 - val_accuracy: 0.6766 - val_loss: 0.6204 - learning_rate: 0.0010
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8529 - loss: 0.4121 - val_accuracy: 0.7391 - val_loss: 0.5630 - learning_rate: 0.0010
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9515 - loss: 0.1654 - val_accuracy: 0.7266 - val_loss: 0.7419 - learning_rate: 0.0010
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9901 - loss: 0.0453 - val_accuracy: 0.7156 - val_loss: 0.9113 - learning_rate: 0.0010
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9976 - loss: 0.0149 - val_accuracy: 0.7063 - val_loss: 1.1038 - learning_rate: 0.0010
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9998 - loss: 0.0057 - val_accuracy: 0.7031 - val_loss: 1.1340 - learning_rate: 5.0000e-04
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.7016 - val_loss: 1.1879 - learning_rate: 5.0000e-04
# 1D CNN - Test Accuracy: 0.6900
#
# Training BiLSTM...
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.4956 - loss: 0.6966 - val_accuracy: 0.6453 - val_loss: 0.6601 - learning_rate: 0.0010
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.7341 - loss: 0.5572 - val_accuracy: 0.7266 - val_loss: 0.5734 - learning_rate: 0.0010
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9119 - loss: 0.2295 - val_accuracy: 0.7031 - val_loss: 0.7004 - learning_rate: 0.0010
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9763 - loss: 0.0802 - val_accuracy: 0.6938 - val_loss: 1.4750 - learning_rate: 0.0010
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9960 - loss: 0.0192 - val_accuracy: 0.7016 - val_loss: 1.2749 - learning_rate: 0.0010
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9964 - loss: 0.0172 - val_accuracy: 0.7016 - val_loss: 1.5654 - learning_rate: 5.0000e-04
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9968 - loss: 0.0092 - val_accuracy: 0.6922 - val_loss: 1.8320 - learning_rate: 5.0000e-04
# BiLSTM - Test Accuracy: 0.6787
#
# Training LSTM...
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.5198 - loss: 0.6935 - val_accuracy: 0.5172 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5105 - loss: 0.6932 - val_accuracy: 0.5172 - val_loss: 0.6927 - learning_rate: 0.0010
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5019 - loss: 0.6935 - val_accuracy: 0.5172 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.4716 - loss: 0.6941 - val_accuracy: 0.5172 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4969 - loss: 0.6937 - val_accuracy: 0.5172 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5034 - loss: 0.6931 - val_accuracy: 0.5172 - val_loss: 0.6930 - learning_rate: 5.0000e-04
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4965 - loss: 0.6932 - val_accuracy: 0.5172 - val_loss: 0.6931 - learning_rate: 5.0000e-04
# LSTM - Test Accuracy: 0.4725
#
# Model Comparison:
# 1D CNN: Test Accuracy = 0.6900
# BiLSTM: Test Accuracy = 0.6787
# LSTM: Test Accuracy = 0.4725
